# %%
from helpers import *

# %%
###### Section 1 ######
###### Calculation of the eigenpairs for the random field ###### 

# Inputs
# 3, 100 takes approximately 5 minutes
mesh_resolution_c_entries = 3
mc_samples_for_c_entries = 100

# Calculate the eigenpairs
randomfieldV, jacobianV = calculate_vector_field_eigenpairs(mesh_resolution_c_entries, mc_samples_for_c_entries)
# Out:
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 63 nodes for 32 points.

# %%
###### Section 2 ######
###### Sobol Index Estimates ######

# Inputs

# Times for only double loop MC:
#   3, 4, 3 takes approximately 2,5 minutes
#   8, 4, 3 takes approximately 14 minutes -> result index123: 0.3, index4: 0.07

# Times for double loop MC and pick freeze:
#   6, 4, 3 takes approximately 32 minutes
mc_sample_size = 6
mesh_resolution_fem = 4
size_of_xi = 3 #! maximum size_of_xi = jacobianV.J
P = fe.Point(0, 0)


indices = [1, 2, 3] # [1, 2, 3] are all xi
double_loop_mc_closed_sobol_index_123 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, indices, jacobianV, size_of_xi)

indices = [4] # [4] is f
double_loop_mc_closed_sobol_index_4 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, indices, jacobianV, size_of_xi)

indices = [1, 2, 3] # [1, 2, 3] are all xi
pick_freeze_closed_sobol_index_123 = pick_freeze(mc_sample_size, mesh_resolution_fem, P, indices, jacobianV, size_of_xi)

indices = [4] # [4] is f
pick_freeze_closed_sobol_index_4 = pick_freeze(mc_sample_size, mesh_resolution_fem, P, indices, jacobianV, size_of_xi)

print(f"Double loop MC closed sobol index 123: {double_loop_mc_closed_sobol_index_123}")
print(f"Double loop MC closed sobol index 4: {double_loop_mc_closed_sobol_index_4}")
print(f"Pick freeze closed sobol index 123: {pick_freeze_closed_sobol_index_123}")
print(f"Pick freeze closed sobol index 4: {pick_freeze_closed_sobol_index_4}")
# Out:
# First loop: Outer MC loop iteration 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Second loop: 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Solving linear variational problem.
# Second loop: 1 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 6
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Double loop MC closed sobol index 123 with double loop mc: 0.005034270997462072
# Double loop MC closed sobol index 4 with double loop mc: 0.37425295363721256
# Pick freeze closed sobol index 123 with double loop mc: 0.0016324872836318205
# Pick freeze closed sobol index 4 with double loop mc: 0.6462744470032525

# %%
# Compare sobol indices for the samples of xi

# Inputs
# 10, 4, 3 takes approximately 35 minutes
mc_sample_size = 10
mesh_resolution_fem = 4
size_of_xi = 3
P = fe.Point(0, 0)

s_1 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [1], jacobianV, size_of_xi)
s_2 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [2], jacobianV, size_of_xi)
s_3 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [3], jacobianV, size_of_xi)

print(f"S_1: {s_1}, S_2: {s_2}, S_3: {s_3}")
# Out:
# First loop: Outer MC loop iteration 1 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 5 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 6 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 7 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 8 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 9 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 10 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 1 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 7 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 8 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 9 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 10 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 1 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 5 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 6 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 7 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 8 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 9 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 10 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 1 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 7 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 8 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 9 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 10 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 1 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 5 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 6 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 7 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 8 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 9 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 10 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 1 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 2 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 3 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 4 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 5 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 6 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 7 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 8 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 9 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Second loop: 10 / 10
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# S_1: 0.05486823493653594, S_2: 0.006767369040286148, S_3: 0.15602167651421692

# %%
# Sobol Index estimation by rank statistics

# Inputs
# 5, 4, 3 takes approximately 2 minutes
mc_sample_size = 5
mesh_resolution_fem = 4
size_of_xi = 3
P = fe.Point(0, 0)

index = 1
s_1 = rank_statistics(mc_sample_size, mesh_resolution_fem, P, index, jacobianV, size_of_xi)

index = 4
s_4 = rank_statistics(mc_sample_size, mesh_resolution_fem, P, index, jacobianV, size_of_xi)

print(f"Rank statistics estimates: S_1: {s_1}, S_4: {s_4}")
# Out:
# Loop: 1 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 2 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 3 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 4 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 5 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 1 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 2 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 3 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 4 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Loop: 5 / 5
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving linear variational problem.
# Rank statistics estimates: S_1: -0.1091179514109489, S_4: -0.38476942113592305
