# %% [markdown]
# $$- \Delta u(x) = F_1 \cdot \sin(\lVert x \rVert_2) + F_2 \cdot \cos(\lVert x \rVert_2) \hspace{0.2cm} \text{on} \hspace{0.2cm} D(\omega_2)$$
# $$ F_1, F_2 \sim \mathbb{U}([0, 1]) $$

# %%
from helpers import *
from helpers_rhs_random import *

# %%
MESH_RESOLUTION_RANDOM_FIELD_CALCULATION = 4

# %%
# Calculate the eigenpairs
# for MESH_RESOLUTION_RANDOM_FIELD_CALCULATION = 4 it takes 1:30 minutes
randomFieldV, jacobianV = calculate_vector_field_eigenpairs(MESH_RESOLUTION_RANDOM_FIELD_CALCULATION)

# %%
###### Section 2 ######
###### Sobol Index Estimates ######

# Inputs

# Times for double loop MC and pick freeze:
#   
mc_sample_size = 4
mesh_resolution_fem = 3
size_of_xi = 3
P = fe.Point(0, 0) #! assumed that P lays in the non-varying domain, should check beforehands


if size_of_xi > jacobianV.J:
    raise ValueError(f"size_of_xi must be less than or equal to {jacobianV.J}")


indices = [1, 2, 3] # [1, 2, 3] are all xi
double_loop_mc_closed_sobol_index_123 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, indices, randomFieldV, jacobianV, size_of_xi)

indices = [4, 5] # [4, 5] are F1 and F2
double_loop_mc_closed_sobol_index_45 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, indices, randomFieldV, jacobianV, size_of_xi)

indices = [1, 2, 3] # [1, 2, 3] are all xi
pick_freeze_closed_sobol_index_123 = pick_freeze(mc_sample_size, mesh_resolution_fem, P, indices, randomFieldV, jacobianV, size_of_xi)

indices = [4, 5] # [4, 5] are F1 and F2
pick_freeze_closed_sobol_index_45 = pick_freeze(mc_sample_size, mesh_resolution_fem, P, indices, randomFieldV, jacobianV, size_of_xi)

print(f"Double loop MC closed sobol index 123: {double_loop_mc_closed_sobol_index_123}")
print(f"Double loop MC closed sobol index 45: {double_loop_mc_closed_sobol_index_45}")
print(f"Pick freeze closed sobol index 123: {pick_freeze_closed_sobol_index_123}")
print(f"Pick freeze closed sobol index 45: {pick_freeze_closed_sobol_index_45}")
# Out:
# First loop: Outer MC loop iteration 1 / 4
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 121 nodes for 61 points.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Second loop: 1 / 4
# Solving linear variational problem.
# Second loop: 2 / 4
# Solving linear variational problem.
# Second loop: 3 / 4
# Solving linear variational problem.
# Second loop: 4 / 4
# Solving linear variational problem.
# First loop: Outer MC loop iteration 1 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 4 / 4
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Second loop: 1 / 4
# Solving linear variational problem.
# Second loop: 2 / 4
# Solving linear variational problem.
# Second loop: 3 / 4
# Solving linear variational problem.
# Second loop: 4 / 4
# Solving linear variational problem.
# First loop: 1 / 4
# indices: [0, 1, 2]
# xi: [-0.94219376 -1.68057839  1.13539798]
# xi_prime: [-0.94219376 -1.68057839  1.13539798]
# F_samples: [0.46254045 0.        ]
# F_samples_prime: [0.58255378 0.        ]
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 2 / 4
# indices: [0, 1, 2]
# xi: [ 1.37782306 -0.32364217 -0.01984623]
# xi_prime: [ 1.37782306 -0.32364217 -0.01984623]
# F_samples: [0.41786535 0.        ]
# F_samples_prime: [0.34266699 0.        ]
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 3 / 4
# indices: [0, 1, 2]
# xi: [ 1.48739485 -1.33267949 -1.71507569]
# xi_prime: [ 1.48739485 -1.33267949 -1.71507569]
# F_samples: [0.93822938 0.        ]
# F_samples_prime: [0.38129736 0.        ]
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 4 / 4
# indices: [0, 1, 2]
# xi: [ 1.20063641 -1.36143434  0.44178559]
# xi_prime: [ 1.20063641 -1.36143434  0.44178559]
# F_samples: [0.00163973 0.        ]
# F_samples_prime: [0.4492605 0.       ]
# Solving linear variational problem.
# Solving linear variational problem.
# Second loop: 1 / 4
# Solving linear variational problem.
# Second loop: 2 / 4
# Solving linear variational problem.
# Second loop: 3 / 4
# Solving linear variational problem.
# Second loop: 4 / 4
# Solving linear variational problem.
# First loop: 1 / 4
# indices: [3, 4]
# xi: [0.08575399 0.71895158 0.89960669]
# xi_prime: [-0.81053085  0.90958662 -0.00358972]
# F_samples: [0.50827713 0.93855879]
# F_samples_prime: [0.50827713 0.93855879]
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 2 / 4
# indices: [3, 4]
# xi: [-0.03128934 -1.13992184  0.74373511]
# xi_prime: [1.40978039 0.88487357 1.72423167]
# F_samples: [0.7631635  0.73129493]
# F_samples_prime: [0.7631635  0.73129493]
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 3 / 4
# indices: [3, 4]
# xi: [-0.8134311   1.43004741  0.82377659]
# xi_prime: [-1.63020898  0.01844454  0.81832507]
# F_samples: [0.78838836 0.50689025]
# F_samples_prime: [0.78838836 0.50689025]
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: 4 / 4
# indices: [3, 4]
# xi: [0.944014   1.10626612 0.77607711]
# xi_prime: [ 1.28879842 -1.5861855   1.48974588]
# F_samples: [0.34439514 0.41892498]
# F_samples_prime: [0.34439514 0.41892498]
# Solving linear variational problem.
# Solving linear variational problem.
# Second loop: 1 / 4
# Solving linear variational problem.
# Second loop: 2 / 4
# Solving linear variational problem.
# Second loop: 3 / 4
# Solving linear variational problem.
# Second loop: 4 / 4
# Solving linear variational problem.
# Double loop MC closed sobol index 123: 0.09910536093354456
# Double loop MC closed sobol index 45: 0.5494806838899707
# Pick freeze closed sobol index 123: -0.040260860230553926
# Pick freeze closed sobol index 45: 0.8357260033400955

# %%
# Compare sobol indices for the samples of xi

# Inputs
# 10, 4, 3 takes approximately 35 minutes
mc_sample_size = 10
mesh_resolution_fem = 3
size_of_xi = 3
P = fe.Point(0, 0) #! assumed that P lays in the non-varying domain


if size_of_xi > jacobianV.J:
    raise ValueError(f"size_of_xi must be less than or equal to {jacobianV.J}")

s_1 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [1], randomFieldV, jacobianV, size_of_xi)
s_2 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [2], randomFieldV, jacobianV, size_of_xi)
s_3 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [3], randomFieldV, jacobianV, size_of_xi)

print(f"S_1: {s_1}, S_2: {s_2}, S_3: {s_3}")
# Out:
# First loop: Outer MC loop iteration 1 / 10
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 2 / 10
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# Solving linear variational problem.
# First loop: Outer MC loop iteration 3 / 10
# Solving linear variational problem.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      11 if size_of_xi > jacobianV.J:
#      12     raise ValueError(f"size_of_xi must be less than or equal to {jacobianV.J}")
# ---> 14 s_1 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [1], randomFieldV, jacobianV, size_of_xi)
#      15 s_2 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [2], randomFieldV, jacobianV, size_of_xi)
#      16 s_3 = double_loop_mc(mc_sample_size, mesh_resolution_fem, P, [3], randomFieldV, jacobianV, size_of_xi)
#
# File ~/git/Masterthesis/const_basis/helpers_rhs_random.py:61, in double_loop_mc(mc_sample_size, mesh_resolution_fem, P, indices, randomFieldV, jacobianV, size_of_xi)
#      59         sols_point_P.append(solve_poisson_for_given_sample_rhs_random(mesh_resolution_fem, jacobianV, xi, F_samples)(P_hat))
#      60     mean_sols_point_P[i] = np.mean(sols_point_P)
# ---> 61 var_A = np.var(mean_sols_point_P, ddof=1)
#      62 sols_point_P = []
#      63 for i in range(mc_sample_size):
#
# File ~/git/Masterthesis/const_basis/helpers_rhs_random.py:33, in solve_poisson_for_given_sample_rhs_random(mesh_resolution, jacobianV, xi, F_samples)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniconda3/envs/fenics_x64/lib/python3.12/site-packages/dolfin/fem/solving.py:220, in solve(*args, **kwargs)
#     217 # Call variational problem solver if we get an equation (but not a
#     218 # tolerance)
#     219 elif isinstance(args[0], ufl.classes.Equation):
# --> 220     _solve_varproblem(*args, **kwargs)
#     222 # Default case, just call the wrapped C++ solve function
#     223 else:
#     224     if kwargs:
#
# File ~/miniconda3/envs/fenics_x64/lib/python3.12/site-packages/dolfin/fem/solving.py:247, in _solve_varproblem(*args, **kwargs)
#     245     solver = LinearVariationalSolver(problem)
#     246     solver.parameters.update(solver_parameters)
# --> 247     solver.solve()
#     249 # Solve nonlinear variational problem
#     250 else:
#     251
#     252     # Create Jacobian if missing
#     253     if J is None:
#
# File ~/miniconda3/envs/fenics_x64/lib/python3.12/site-packages/dolfin/function/expression.py:53, in _InterfaceExpression.__init__.<locals>.wrapped_eval(self, values, x)
#      52 def wrapped_eval(self, values, x):
# ---> 53     self.user_expression.eval(values, x)
#
# File ~/git/Masterthesis/const_basis/helpers.py:184, in detJExpression.eval(self, values, x)
#     183 def eval(self, values, x):
# --> 184     J_x = self.jacobianV(x, self.xi)
#     185     det_J = np.linalg.det(J_x)
#     186     values[0] = det_J
#
# File ~/git/Masterthesis/const_basis/helpers.py:150, in JacobianV.__call__(self, x, xi)
#     148     helper[0, 1] = sum([self.eigenvectors[k, j] * quad_tri(v_cov1_1_dx2_expr, self.basis_functions[k]) for k in range(self.N)]) + sum([self.eigenvectors[self.N + k, j] * quad_tri(v_cov1_2_dx2_expr, self.basis_functions[k]) for k in range(self.N)])
#     149     helper[1, 0] = sum([self.eigenvectors[k, j] * quad_tri(v_cov2_1_dx1_expr, self.basis_functions[k]) for k in range(self.N)]) + sum([self.eigenvectors[self.N + k, j] * quad_tri(v_cov2_2_dx1_expr, self.basis_functions[k]) for k in range(self.N)])
# --> 150     helper[1, 1] = sum([self.eigenvectors[k, j] * quad_tri(v_cov2_1_dx2_expr, self.basis_functions[k]) for k in range(self.N)]) + sum([self.eigenvectors[self.N + k, j] * quad_tri(v_cov2_2_dx2_expr, self.basis_functions[k]) for k in range(self.N)])
#     151     eigenfunction_jacobians.append(helper)
#     152 # np.sqrt(self.eigenvalues[j]) / self.eigenvalues[j]
#
# File ~/git/Masterthesis/const_basis/helpers.py:123, in quad_tri(f, basis_function)
#     121 integral = 0
#     122 for quad_point in quad_points:
# --> 123     integral += f(quad_point.point[0], quad_point.point[1]) * basis_function.function(quad_point.point) * quad_point.weight
#     124 return integral
#
# File ~/miniconda3/envs/fenics_x64/lib/python3.12/site-packages/dolfin/function/function.py:337, in Function.__call__(self, *args, **kwargs)
#     333     raise TypeError("expected the geometry argument to be of "
#     334                     "length %d" % dim)
#     336 # The actual evaluation
# --> 337 self._cpp_object.eval(values, x)
#     339 # If scalar return statement, return scalar value.
#     340 if value_size == 1 and not values_provided:
#
# KeyboardInterrupt:

# %%
# Sobol Index estimation by rank statistics

# Inputs
# 5, 4, 3 takes approximately 2 minutes
mc_sample_size = 5
mesh_resolution_fem = 3
size_of_xi = 3
P = fe.Point(0, 0) #! assumed that P lays in the non-varying domain


if size_of_xi > jacobianV.J:
    raise ValueError(f"size_of_xi must be less than or equal to {jacobianV.J}")

index = 1
s_1 = rank_statistics(mc_sample_size, mesh_resolution_fem, P, index, randomFieldV, jacobianV, size_of_xi)

index = 4
s_4 = rank_statistics(mc_sample_size, mesh_resolution_fem, P, index, randomFieldV, jacobianV, size_of_xi)

print(f"Rank statistics estimates: S_1: {s_1}, S_4: {s_4}")
# Out:
# Loop: 1 / 5
# Solving linear variational problem.
# Loop: 2 / 5
# Solving linear variational problem.
# Loop: 3 / 5
# Solving linear variational problem.
# Loop: 4 / 5
# Solving linear variational problem.
# Loop: 5 / 5
# Solving linear variational problem.
# Loop: 1 / 5
# Solving linear variational problem.
# Loop: 2 / 5
# Solving linear variational problem.
# Loop: 3 / 5
# Solving linear variational problem.
# Loop: 4 / 5
# Solving linear variational problem.
# Loop: 5 / 5
# Solving linear variational problem.
# Rank statistics estimates: S_1: -0.7791656796141453, S_4: -0.6973074504920728

# %%
# Test algorithms with test function
# samples sizes 1.000, 10.000, 50.000 take approx. 
double_loop_sample_size = 1000
pick_freeze_sample_size = 10000
rank_statistics_sample_size = 10000 #! don't know there the error is, maybe try with more samples (like 100.000)
mesh_resolution_fem = 3
size_of_xi = 3
P = fe.Point(0, 0) #! assumed that P lays in the non-varying domain, should check beforehands

double_loop_s1 = double_loop_mc(double_loop_sample_size, mesh_resolution_fem, P, [1], randomFieldV, jacobianV, size_of_xi, test=True)
pick_freeze_s1 = pick_freeze(pick_freeze_sample_size, mesh_resolution_fem, P, [1], randomFieldV, jacobianV, size_of_xi, test=True)
rank_statistics_s1 = rank_statistics(rank_statistics_sample_size, mesh_resolution_fem, P, 1, randomFieldV, jacobianV, size_of_xi, test=True)

print(f"Double loop MC S_1: {double_loop_s1}")
print(f"Pick freeze S_1: {pick_freeze_s1}")
print(f"Rank statistics S_1: {rank_statistics_s1}")
# Out:
# First loop: Outer MC loop iteration 1 / 1000
# First loop: Outer MC loop iteration 2 / 1000
# First loop: Outer MC loop iteration 3 / 1000
# First loop: Outer MC loop iteration 4 / 1000
# First loop: Outer MC loop iteration 5 / 1000
# First loop: Outer MC loop iteration 6 / 1000
# First loop: Outer MC loop iteration 7 / 1000
# First loop: Outer MC loop iteration 8 / 1000
# First loop: Outer MC loop iteration 9 / 1000
# First loop: Outer MC loop iteration 10 / 1000
# First loop: Outer MC loop iteration 11 / 1000
# First loop: Outer MC loop iteration 12 / 1000
# First loop: Outer MC loop iteration 13 / 1000
# First loop: Outer MC loop iteration 14 / 1000
# First loop: Outer MC loop iteration 15 / 1000
# First loop: Outer MC loop iteration 16 / 1000
# First loop: Outer MC loop iteration 17 / 1000
# First loop: Outer MC loop iteration 18 / 1000
# First loop: Outer MC loop iteration 19 / 1000
# First loop: Outer MC loop iteration 20 / 1000
# First loop: Outer MC loop iteration 21 / 1000
# First loop: Outer MC loop iteration 22 / 1000
# First loop: Outer MC loop iteration 23 / 1000
# First loop: Outer MC loop iteration 24 / 1000
# First loop: Outer MC loop iteration 25 / 1000
# First loop: Outer MC loop iteration 26 / 1000
# First loop: Outer MC loop iteration 27 / 1000
# First loop: Outer MC loop iteration 28 / 1000
# First loop: Outer MC loop iteration 29 / 1000
# First loop: Outer MC loop iteration 30 / 1000
# First loop: Outer MC loop iteration 31 / 1000
# First loop: Outer MC loop iteration 32 / 1000
# First loop: Outer MC loop iteration 33 / 1000
# First loop: Outer MC loop iteration 34 / 1000
# First loop: Outer MC loop iteration 35 / 1000
# First loop: Outer MC loop iteration 36 / 1000
# First loop: Outer MC loop iteration 37 / 1000
# First loop: Outer MC loop iteration 38 / 1000
# First loop: Outer MC loop iteration 39 / 1000
# First loop: Outer MC loop iteration 40 / 1000
# First loop: Outer MC loop iteration 41 / 1000
# First loop: Outer MC loop iteration 42 / 1000
# First loop: Outer MC loop iteration 43 / 1000
# First loop: Outer MC loop iteration 44 / 1000
# First loop: Outer MC loop iteration 45 / 1000
# First loop: Outer MC loop iteration 46 / 1000
# First loop: Outer MC loop iteration 47 / 1000
# First loop: Outer MC loop iteration 48 / 1000
# First loop: Outer MC loop iteration 49 / 1000
# First loop: Outer MC loop iteration 50 / 1000
# First loop: Outer MC loop iteration 51 / 1000
# First loop: Outer MC loop iteration 52 / 1000
# First loop: Outer MC loop iteration 53 / 1000
# First loop: Outer MC loop iteration 54 / 1000
# First loop: Outer MC loop iteration 55 / 1000
# First loop: Outer MC loop iteration 56 / 1000
# First loop: Outer MC loop iteration 57 / 1000
# First loop: Outer MC loop iteration 58 / 1000
# First loop: Outer MC loop iteration 59 / 1000
# First loop: Outer MC loop iteration 60 / 1000
# First loop: Outer MC loop iteration 61 / 1000
# First loop: Outer MC loop iteration 62 / 1000
# First loop: Outer MC loop iteration 63 / 1000
# First loop: Outer MC loop iteration 64 / 1000
# First loop: Outer MC loop iteration 65 / 1000
# First loop: Outer MC loop iteration 66 / 1000
# First loop: Outer MC loop iteration 67 / 1000
# First loop: Outer MC loop iteration 68 / 1000
# First loop: Outer MC loop iteration 69 / 1000
# First loop: Outer MC loop iteration 70 / 1000
# First loop: Outer MC loop iteration 71 / 1000
# First loop: Outer MC loop iteration 72 / 1000
# First loop: Outer MC loop iteration 73 / 1000
# First loop: Outer MC loop iteration 74 / 1000
# First loop: Outer MC loop iteration 75 / 1000
# First loop: Outer MC loop iteration 76 / 1000
# First loop: Outer MC loop iteration 77 / 1000
# First loop: Outer MC loop iteration 78 / 1000
# First loop: Outer MC loop iteration 79 / 1000
# First loop: Outer MC loop iteration 80 / 1000
# First loop: Outer MC loop iteration 81 / 1000
# First loop: Outer MC loop iteration 82 / 1000
# First loop: Outer MC loop iteration 83 / 1000
# First loop: Outer MC loop iteration 84 / 1000
# First loop: Outer MC loop iteration 85 / 1000
# First loop: Outer MC loop iteration 86 / 1000
# First loop: Outer MC loop iteration 87 / 1000
# First loop: Outer MC loop iteration 88 / 1000
# First loop: Outer MC loop iteration 89 / 1000
# First loop: Outer MC loop iteration 90 / 1000
# First loop: Outer MC loop iteration 91 / 1000
# First loop: Outer MC loop iteration 92 / 1000
# First loop: Outer MC loop iteration 93 / 1000
# First loop: Outer MC loop iteration 94 / 1000
# First loop: Outer MC loop iteration 95 / 1000
# First loop: Outer MC loop iteration 96 / 1000
# First loop: Outer MC loop iteration 97 / 1000
# First loop: Outer MC loop iteration 98 / 1000
# First loop: Outer MC loop iteration 99 / 1000
# First loop: Outer MC loop iteration 100 / 1000
# First loop: Outer MC loop iteration 101 / 1000
# First loop: Outer MC loop iteration 102 / 1000
# First loop: Outer MC loop iteration 103 / 1000
# First loop: Outer MC loop iteration 104 / 1000
# First loop: Outer MC loop iteration 105 / 1000
# First loop: Outer MC loop iteration 106 / 1000
# First loop: Outer MC loop iteration 107 / 1000
# First loop: Outer MC loop iteration 108 / 1000
# First loop: Outer MC loop iteration 109 / 1000
# First loop: Outer MC loop iteration 110 / 1000
# First loop: Outer MC loop iteration 111 / 1000
# First loop: Outer MC loop iteration 112 / 1000
# First loop: Outer MC loop iteration 113 / 1000
# First loop: Outer MC loop iteration 114 / 1000
# First loop: Outer MC loop iteration 115 / 1000
# First loop: Outer MC loop iteration 116 / 1000
# First loop: Outer MC loop iteration 117 / 1000
# First loop: Outer MC loop iteration 118 / 1000
# First loop: Outer MC loop iteration 119 / 1000
# First loop: Outer MC loop iteration 120 / 1000
# First loop: Outer MC loop iteration 121 / 1000
# First loop: Outer MC loop iteration 122 / 1000
# First loop: Outer MC loop iteration 123 / 1000
# First loop: Outer MC loop iteration 124 / 1000
# First loop: Outer MC loop iteration 125 / 1000
# First loop: Outer MC loop iteration 126 / 1000
# First loop: Outer MC loop iteration 127 / 1000
# First loop: Outer MC loop iteration 128 / 1000
# First loop: Outer MC loop iteration 129 / 1000
# First loop: Outer MC loop iteration 130 / 1000
# First loop: Outer MC loop iteration 131 / 1000
# First loop: Outer MC loop iteration 132 / 1000
# First loop: Outer MC loop iteration 133 / 1000
# First loop: Outer MC loop iteration 134 / 1000
# First loop: Outer MC loop iteration 135 / 1000
# First loop: Outer MC loop iteration 136 / 1000
# First loop: Outer MC loop iteration 137 / 1000
# First loop: Outer MC loop iteration 138 / 1000
# First loop: Outer MC loop iteration 139 / 1000
# First loop: Outer MC loop iteration 140 / 1000
# First loop: Outer MC loop iteration 141 / 1000
# First loop: Outer MC loop iteration 142 / 1000
# First loop: Outer MC loop iteration 143 / 1000
# First loop: Outer MC loop iteration 144 / 1000
# First loop: Outer MC loop iteration 145 / 1000
# First loop: Outer MC loop iteration 146 / 1000
# First loop: Outer MC loop iteration 147 / 1000
# First loop: Outer MC loop iteration 148 / 1000
# First loop: Outer MC loop iteration 149 / 1000
# First loop: Outer MC loop iteration 150 / 1000
# First loop: Outer MC loop iteration 151 / 1000
# First loop: Outer MC loop iteration 152 / 1000
# First loop: Outer MC loop iteration 153 / 1000
# First loop: Outer MC loop iteration 154 / 1000
# First loop: Outer MC loop iteration 155 / 1000
# First loop: Outer MC loop iteration 156 / 1000
# First loop: Outer MC loop iteration 157 / 1000
# First loop: Outer MC loop iteration 158 / 1000
# First loop: Outer MC loop iteration 159 / 1000
# First loop: Outer MC loop iteration 160 / 1000
# First loop: Outer MC loop iteration 161 / 1000
# First loop: Outer MC loop iteration 162 / 1000
# First loop: Outer MC loop iteration 163 / 1000
# First loop: Outer MC loop iteration 164 / 1000
# First loop: Outer MC loop iteration 165 / 1000
# First loop: Outer MC loop iteration 166 / 1000
# First loop: Outer MC loop iteration 167 / 1000
# First loop: Outer MC loop iteration 168 / 1000
# First loop: Outer MC loop iteration 169 / 1000
# First loop: Outer MC loop iteration 170 / 1000
# First loop: Outer MC loop iteration 171 / 1000
# First loop: Outer MC loop iteration 172 / 1000
# First loop: Outer MC loop iteration 173 / 1000
# First loop: Outer MC loop iteration 174 / 1000
# First loop: Outer MC loop iteration 175 / 1000
# First loop: Outer MC loop iteration 176 / 1000
# First loop: Outer MC loop iteration 177 / 1000
# First loop: Outer MC loop iteration 178 / 1000
# First loop: Outer MC loop iteration 179 / 1000
# First loop: Outer MC loop iteration 180 / 1000
# First loop: Outer MC loop iteration 181 / 1000
# First loop: Outer MC loop iteration 182 / 1000
# First loop: Outer MC loop iteration 183 / 1000
# First loop: Outer MC loop iteration 184 / 1000
# First loop: Outer MC loop iteration 185 / 1000
# First loop: Outer MC loop iteration 186 / 1000
# First loop: Outer MC loop iteration 187 / 1000
# First loop: Outer MC loop iteration 188 / 1000
# First loop: Outer MC loop iteration 189 / 1000
# First loop: Outer MC loop iteration 190 / 1000
# First loop: Outer MC loop iteration 191 / 1000
# First loop: Outer MC loop iteration 192 / 1000
# First loop: Outer MC loop iteration 193 / 1000
# First loop: Outer MC loop iteration 194 / 1000
# First loop: Outer MC loop iteration 195 / 1000
# First loop: Outer MC loop iteration 196 / 1000
# First loop: Outer MC loop iteration 197 / 1000
# First loop: Outer MC loop iteration 198 / 1000
# First loop: Outer MC loop iteration 199 / 1000
# First loop: Outer MC loop iteration 200 / 1000
# First loop: Outer MC loop iteration 201 / 1000
# First loop: Outer MC loop iteration 202 / 1000
# First loop: Outer MC loop iteration 203 / 1000
# First loop: Outer MC loop iteration 204 / 1000
# First loop: Outer MC loop iteration 205 / 1000
# First loop: Outer MC loop iteration 206 / 1000
# First loop: Outer MC loop iteration 207 / 1000
# First loop: Outer MC loop iteration 208 / 1000
# First loop: Outer MC loop iteration 209 / 1000
# First loop: Outer MC loop iteration 210 / 1000
# First loop: Outer MC loop iteration 211 / 1000
# First loop: Outer MC loop iteration 212 / 1000
# First loop: Outer MC loop iteration 213 / 1000
# First loop: Outer MC loop iteration 214 / 1000
# First loop: Outer MC loop iteration 215 / 1000
# First loop: Outer MC loop iteration 216 / 1000
# First loop: Outer MC loop iteration 217 / 1000
# First loop: Outer MC loop iteration 218 / 1000
# First loop: Outer MC loop iteration 219 / 1000
# First loop: Outer MC loop iteration 220 / 1000
# First loop: Outer MC loop iteration 221 / 1000
# First loop: Outer MC loop iteration 222 / 1000
# First loop: Outer MC loop iteration 223 / 1000
# First loop: Outer MC loop iteration 224 / 1000
# First loop: Outer MC loop iteration 225 / 1000
# First loop: Outer MC loop iteration 226 / 1000
# First loop: Outer MC loop iteration 227 / 1000
# First loop: Outer MC loop iteration 228 / 1000
# First loop: Outer MC loop iteration 229 / 1000
# First loop: Outer MC loop iteration 230 / 1000
# First loop: Outer MC loop iteration 231 / 1000
# First loop: Outer MC loop iteration 232 / 1000
# First loop: Outer MC loop iteration 233 / 1000
# First loop: Outer MC loop iteration 234 / 1000
# First loop: Outer MC loop iteration 235 / 1000
# First loop: Outer MC loop iteration 236 / 1000
# First loop: Outer MC loop iteration 237 / 1000
# First loop: Outer MC loop iteration 238 / 1000
# First loop: Outer MC loop iteration 239 / 1000
# First loop: Outer MC loop iteration 240 / 1000
# First loop: Outer MC loop iteration 241 / 1000
# First loop: Outer MC loop iteration 242 / 1000
# First loop: Outer MC loop iteration 243 / 1000
# First loop: Outer MC loop iteration 244 / 1000
# First loop: Outer MC loop iteration 245 / 1000
# First loop: Outer MC loop iteration 246 / 1000
# First loop: Outer MC loop iteration 247 / 1000
# First loop: Outer MC loop iteration 248 / 1000
# First loop: Outer MC loop iteration 249 / 1000
# First loop: Outer MC loop iteration 250 / 1000
# First loop: Outer MC loop iteration 251 / 1000
# First loop: Outer MC loop iteration 252 / 1000
# First loop: Outer MC loop iteration 253 / 1000
# First loop: Outer MC loop iteration 254 / 1000
# First loop: Outer MC loop iteration 255 / 1000
# First loop: Outer MC loop iteration 256 / 1000
# First loop: Outer MC loop iteration 257 / 1000
# First loop: Outer MC loop iteration 258 / 1000
# First loop: Outer MC loop iteration 259 / 1000
# First loop: Outer MC loop iteration 260 / 1000
# First loop: Outer MC loop iteration 261 / 1000
# First loop: Outer MC loop iteration 262 / 1000
# First loop: Outer MC loop iteration 263 / 1000
# First loop: Outer MC loop iteration 264 / 1000
# First loop: Outer MC loop iteration 265 / 1000
# First loop: Outer MC loop iteration 266 / 1000
# First loop: Outer MC loop iteration 267 / 1000
# First loop: Outer MC loop iteration 268 / 1000
# First loop: Outer MC loop iteration 269 / 1000
# First loop: Outer MC loop iteration 270 / 1000
# First loop: Outer MC loop iteration 271 / 1000
# First loop: Outer MC loop iteration 272 / 1000
# First loop: Outer MC loop iteration 273 / 1000
# First loop: Outer MC loop iteration 274 / 1000
# First loop: Outer MC loop iteration 275 / 1000
# First loop: Outer MC loop iteration 276 / 1000
# First loop: Outer MC loop iteration 277 / 1000
# First loop: Outer MC loop iteration 278 / 1000
# First loop: Outer MC loop iteration 279 / 1000
# First loop: Outer MC loop iteration 280 / 1000
# First loop: Outer MC loop iteration 281 / 1000
# First loop: Outer MC loop iteration 282 / 1000
# First loop: Outer MC loop iteration 283 / 1000
# First loop: Outer MC loop iteration 284 / 1000
# First loop: Outer MC loop iteration 285 / 1000
# First loop: Outer MC loop iteration 286 / 1000
# First loop: Outer MC loop iteration 287 / 1000
# First loop: Outer MC loop iteration 288 / 1000
# First loop: Outer MC loop iteration 289 / 1000
# First loop: Outer MC loop iteration 290 / 1000
# First loop: Outer MC loop iteration 291 / 1000
# First loop: Outer MC loop iteration 292 / 1000
# First loop: Outer MC loop iteration 293 / 1000
# First loop: Outer MC loop iteration 294 / 1000
# First loop: Outer MC loop iteration 295 / 1000
# First loop: Outer MC loop iteration 296 / 1000
# First loop: Outer MC loop iteration 297 / 1000
# First loop: Outer MC loop iteration 298 / 1000
# First loop: Outer MC loop iteration 299 / 1000
# First loop: Outer MC loop iteration 300 / 1000
# First loop: Outer MC loop iteration 301 / 1000
# First loop: Outer MC loop iteration 302 / 1000
# First loop: Outer MC loop iteration 303 / 1000
# First loop: Outer MC loop iteration 304 / 1000
# First loop: Outer MC loop iteration 305 / 1000
# First loop: Outer MC loop iteration 306 / 1000
# First loop: Outer MC loop iteration 307 / 1000
# First loop: Outer MC loop iteration 308 / 1000
# First loop: Outer MC loop iteration 309 / 1000
# First loop: Outer MC loop iteration 310 / 1000
# First loop: Outer MC loop iteration 311 / 1000
# First loop: Outer MC loop iteration 312 / 1000
# First loop: Outer MC loop iteration 313 / 1000
# First loop: Outer MC loop iteration 314 / 1000
# First loop: Outer MC loop iteration 315 / 1000
# First loop: Outer MC loop iteration 316 / 1000
# First loop: Outer MC loop iteration 317 / 1000
# First loop: Outer MC loop iteration 318 / 1000
# First loop: Outer MC loop iteration 319 / 1000
# First loop: Outer MC loop iteration 320 / 1000
# First loop: Outer MC loop iteration 321 / 1000
# First loop: Outer MC loop iteration 322 / 1000
# First loop: Outer MC loop iteration 323 / 1000
# First loop: Outer MC loop iteration 324 / 1000
# First loop: Outer MC loop iteration 325 / 1000
# First loop: Outer MC loop iteration 326 / 1000
# First loop: Outer MC loop iteration 327 / 1000
# First loop: Outer MC loop iteration 328 / 1000
# First loop: Outer MC loop iteration 329 / 1000
# First loop: Outer MC loop iteration 330 / 1000
# First loop: Outer MC loop iteration 331 / 1000
# First loop: Outer MC loop iteration 332 / 1000
# First loop: Outer MC loop iteration 333 / 1000
# First loop: Outer MC loop iteration 334 / 1000
# First loop: Outer MC loop iteration 335 / 1000
# First loop: Outer MC loop iteration 336 / 1000
# First loop: Outer MC loop iteration 337 / 1000
# First loop: Outer MC loop iteration 338 / 1000
# First loop: Outer MC loop iteration 339 / 1000
# First loop: Outer MC loop iteration 340 / 1000
# First loop: Outer MC loop iteration 341 / 1000
# First loop: Outer MC loop iteration 342 / 1000
# First loop: Outer MC loop iteration 343 / 1000
# First loop: Outer MC loop iteration 344 / 1000
# First loop: Outer MC loop iteration 345 / 1000
# First loop: Outer MC loop iteration 346 / 1000
# First loop: Outer MC loop iteration 347 / 1000
# First loop: Outer MC loop iteration 348 / 1000
# First loop: Outer MC loop iteration 349 / 1000
# First loop: Outer MC loop iteration 350 / 1000
# First loop: Outer MC loop iteration 351 / 1000
# First loop: Outer MC loop iteration 352 / 1000
# First loop: Outer MC loop iteration 353 / 1000
# First loop: Outer MC loop iteration 354 / 1000
# First loop: Outer MC loop iteration 355 / 1000
# First loop: Outer MC loop iteration 356 / 1000
# First loop: Outer MC loop iteration 357 / 1000
# First loop: Outer MC loop iteration 358 / 1000
# First loop: Outer MC loop iteration 359 / 1000
# First loop: Outer MC loop iteration 360 / 1000
# First loop: Outer MC loop iteration 361 / 1000
# First loop: Outer MC loop iteration 362 / 1000
# First loop: Outer MC loop iteration 363 / 1000
# First loop: Outer MC loop iteration 364 / 1000
# First loop: Outer MC loop iteration 365 / 1000
# First loop: Outer MC loop iteration 366 / 1000
# First loop: Outer MC loop iteration 367 / 1000
# First loop: Outer MC loop iteration 368 / 1000
# First loop: Outer MC loop iteration 369 / 1000
# First loop: Outer MC loop iteration 370 / 1000
# First loop: Outer MC loop iteration 371 / 1000
# First loop: Outer MC loop iteration 372 / 1000
# First loop: Outer MC loop iteration 373 / 1000
# First loop: Outer MC loop iteration 374 / 1000
# First loop: Outer MC loop iteration 375 / 1000
# First loop: Outer MC loop iteration 376 / 1000
# First loop: Outer MC loop iteration 377 / 1000
# First loop: Outer MC loop iteration 378 / 1000
# First loop: Outer MC loop iteration 379 / 1000
# First loop: Outer MC loop iteration 380 / 1000
# First loop: Outer MC loop iteration 381 / 1000
# First loop: Outer MC loop iteration 382 / 1000
# First loop: Outer MC loop iteration 383 / 1000
# First loop: Outer MC loop iteration 384 / 1000
# First loop: Outer MC loop iteration 385 / 1000
# First loop: Outer MC loop iteration 386 / 1000
# First loop: Outer MC loop iteration 387 / 1000
# First loop: Outer MC loop iteration 388 / 1000
# First loop: Outer MC loop iteration 389 / 1000
# First loop: Outer MC loop iteration 390 / 1000
# First loop: Outer MC loop iteration 391 / 1000
# First loop: Outer MC loop iteration 392 / 1000
# First loop: Outer MC loop iteration 393 / 1000
# First loop: Outer MC loop iteration 394 / 1000
# First loop: Outer MC loop iteration 395 / 1000
# First loop: Outer MC loop iteration 396 / 1000
# First loop: Outer MC loop iteration 397 / 1000
# First loop: Outer MC loop iteration 398 / 1000
# First loop: Outer MC loop iteration 399 / 1000
# First loop: Outer MC loop iteration 400 / 1000
# First loop: Outer MC loop iteration 401 / 1000
# First loop: Outer MC loop iteration 402 / 1000
# First loop: Outer MC loop iteration 403 / 1000
# First loop: Outer MC loop iteration 404 / 1000
# First loop: Outer MC loop iteration 405 / 1000
# First loop: Outer MC loop iteration 406 / 1000
# First loop: Outer MC loop iteration 407 / 1000
# First loop: Outer MC loop iteration 408 / 1000
# First loop: Outer MC loop iteration 409 / 1000
# First loop: Outer MC loop iteration 410 / 1000
# First loop: Outer MC loop iteration 411 / 1000
# First loop: Outer MC loop iteration 412 / 1000
# First loop: Outer MC loop iteration 413 / 1000
# First loop: Outer MC loop iteration 414 / 1000
# First loop: Outer MC loop iteration 415 / 1000
# First loop: Outer MC loop iteration 416 / 1000
# First loop: Outer MC loop iteration 417 / 1000
# First loop: Outer MC loop iteration 418 / 1000
# First loop: Outer MC loop iteration 419 / 1000
# First loop: Outer MC loop iteration 420 / 1000
# First loop: Outer MC loop iteration 421 / 1000
# First loop: Outer MC loop iteration 422 / 1000
# First loop: Outer MC loop iteration 423 / 1000
# First loop: Outer MC loop iteration 424 / 1000
# First loop: Outer MC loop iteration 425 / 1000
# First loop: Outer MC loop iteration 426 / 1000
# First loop: Outer MC loop iteration 427 / 1000
# First loop: Outer MC loop iteration 428 / 1000
# First loop: Outer MC loop iteration 429 / 1000
# First loop: Outer MC loop iteration 430 / 1000
# First loop: Outer MC loop iteration 431 / 1000
# First loop: Outer MC loop iteration 432 / 1000
# First loop: Outer MC loop iteration 433 / 1000
# First loop: Outer MC loop iteration 434 / 1000
# First loop: Outer MC loop iteration 435 / 1000
# First loop: Outer MC loop iteration 436 / 1000
# First loop: Outer MC loop iteration 437 / 1000
# First loop: Outer MC loop iteration 438 / 1000
# First loop: Outer MC loop iteration 439 / 1000
# First loop: Outer MC loop iteration 440 / 1000
# First loop: Outer MC loop iteration 441 / 1000
# First loop: Outer MC loop iteration 442 / 1000
# First loop: Outer MC loop iteration 443 / 1000
# First loop: Outer MC loop iteration 444 / 1000
# First loop: Outer MC loop iteration 445 / 1000
# First loop: Outer MC loop iteration 446 / 1000
# First loop: Outer MC loop iteration 447 / 1000
# First loop: Outer MC loop iteration 448 / 1000
# First loop: Outer MC loop iteration 449 / 1000
# First loop: Outer MC loop iteration 450 / 1000
# First loop: Outer MC loop iteration 451 / 1000
# First loop: Outer MC loop iteration 452 / 1000
# First loop: Outer MC loop iteration 453 / 1000
# First loop: Outer MC loop iteration 454 / 1000
# First loop: Outer MC loop iteration 455 / 1000
# First loop: Outer MC loop iteration 456 / 1000
# First loop: Outer MC loop iteration 457 / 1000
# First loop: Outer MC loop iteration 458 / 1000
# First loop: Outer MC loop iteration 459 / 1000
# First loop: Outer MC loop iteration 460 / 1000
# First loop: Outer MC loop iteration 461 / 1000
# First loop: Outer MC loop iteration 462 / 1000
# First loop: Outer MC loop iteration 463 / 1000
# First loop: Outer MC loop iteration 464 / 1000
# First loop: Outer MC loop iteration 465 / 1000
# First loop: Outer MC loop iteration 466 / 1000
# First loop: Outer MC loop iteration 467 / 1000
# First loop: Outer MC loop iteration 468 / 1000
# First loop: Outer MC loop iteration 469 / 1000
# First loop: Outer MC loop iteration 470 / 1000
# First loop: Outer MC loop iteration 471 / 1000
# First loop: Outer MC loop iteration 472 / 1000
# First loop: Outer MC loop iteration 473 / 1000
# First loop: Outer MC loop iteration 474 / 1000
# First loop: Outer MC loop iteration 475 / 1000
# First loop: Outer MC loop iteration 476 / 1000
# First loop: Outer MC loop iteration 477 / 1000
# First loop: Outer MC loop iteration 478 / 1000
# First loop: Outer MC loop iteration 479 / 1000
# First loop: Outer MC loop iteration 480 / 1000
# First loop: Outer MC loop iteration 481 / 1000
# First loop: Outer MC loop iteration 482 / 1000
# First loop: Outer MC loop iteration 483 / 1000
# First loop: Outer MC loop iteration 484 / 1000
# First loop: Outer MC loop iteration 485 / 1000
# First loop: Outer MC loop iteration 486 / 1000
# First loop: Outer MC loop iteration 487 / 1000
# First loop: Outer MC loop iteration 488 / 1000
# First loop: Outer MC loop iteration 489 / 1000
# First loop: Outer MC loop iteration 490 / 1000
# First loop: Outer MC loop iteration 491 / 1000
# First loop: Outer MC loop iteration 492 / 1000
# First loop: Outer MC loop iteration 493 / 1000
# First loop: Outer MC loop iteration 494 / 1000
# First loop: Outer MC loop iteration 495 / 1000
# First loop: Outer MC loop iteration 496 / 1000
# First loop: Outer MC loop iteration 497 / 1000
# First loop: Outer MC loop iteration 498 / 1000
# First loop: Outer MC loop iteration 499 / 1000
# First loop: Outer MC loop iteration 500 / 1000
# First loop: Outer MC loop iteration 501 / 1000
# First loop: Outer MC loop iteration 502 / 1000
# First loop: Outer MC loop iteration 503 / 1000
# First loop: Outer MC loop iteration 504 / 1000
# First loop: Outer MC loop iteration 505 / 1000
# First loop: Outer MC loop iteration 506 / 1000
# First loop: Outer MC loop iteration 507 / 1000
# First loop: Outer MC loop iteration 508 / 1000
# First loop: Outer MC loop iteration 509 / 1000
# First loop: Outer MC loop iteration 510 / 1000
# First loop: Outer MC loop iteration 511 / 1000
# First loop: Outer MC loop iteration 512 / 1000
# First loop: Outer MC loop iteration 513 / 1000
# First loop: Outer MC loop iteration 514 / 1000
# First loop: Outer MC loop iteration 515 / 1000
# First loop: Outer MC loop iteration 516 / 1000
# First loop: Outer MC loop iteration 517 / 1000
# First loop: Outer MC loop iteration 518 / 1000
# First loop: Outer MC loop iteration 519 / 1000
# First loop: Outer MC loop iteration 520 / 1000
# First loop: Outer MC loop iteration 521 / 1000
# First loop: Outer MC loop iteration 522 / 1000
# First loop: Outer MC loop iteration 523 / 1000
# First loop: Outer MC loop iteration 524 / 1000
# First loop: Outer MC loop iteration 525 / 1000
# First loop: Outer MC loop iteration 526 / 1000
# First loop: Outer MC loop iteration 527 / 1000
# First loop: Outer MC loop iteration 528 / 1000
# First loop: Outer MC loop iteration 529 / 1000
# First loop: Outer MC loop iteration 530 / 1000
# First loop: Outer MC loop iteration 531 / 1000
# First loop: Outer MC loop iteration 532 / 1000
# First loop: Outer MC loop iteration 533 / 1000
# First loop: Outer MC loop iteration 534 / 1000
# First loop: Outer MC loop iteration 535 / 1000
# First loop: Outer MC loop iteration 536 / 1000
# First loop: Outer MC loop iteration 537 / 1000
# First loop: Outer MC loop iteration 538 / 1000
# First loop: Outer MC loop iteration 539 / 1000
# First loop: Outer MC loop iteration 540 / 1000
# First loop: Outer MC loop iteration 541 / 1000
# First loop: Outer MC loop iteration 542 / 1000
# First loop: Outer MC loop iteration 543 / 1000
# First loop: Outer MC loop iteration 544 / 1000
# First loop: Outer MC loop iteration 545 / 1000
# First loop: Outer MC loop iteration 546 / 1000
# First loop: Outer MC loop iteration 547 / 1000
# First loop: Outer MC loop iteration 548 / 1000
# First loop: Outer MC loop iteration 549 / 1000
# First loop: Outer MC loop iteration 550 / 1000
# First loop: Outer MC loop iteration 551 / 1000
# First loop: Outer MC loop iteration 552 / 1000
# First loop: Outer MC loop iteration 553 / 1000
# First loop: Outer MC loop iteration 554 / 1000
# First loop: Outer MC loop iteration 555 / 1000
# First loop: Outer MC loop iteration 556 / 1000
# First loop: Outer MC loop iteration 557 / 1000
# First loop: Outer MC loop iteration 558 / 1000
# First loop: Outer MC loop iteration 559 / 1000
# First loop: Outer MC loop iteration 560 / 1000
# First loop: Outer MC loop iteration 561 / 1000
# First loop: Outer MC loop iteration 562 / 1000
# First loop: Outer MC loop iteration 563 / 1000
# First loop: Outer MC loop iteration 564 / 1000
# First loop: Outer MC loop iteration 565 / 1000
# First loop: Outer MC loop iteration 566 / 1000
# First loop: Outer MC loop iteration 567 / 1000
# First loop: Outer MC loop iteration 568 / 1000
# First loop: Outer MC loop iteration 569 / 1000
# First loop: Outer MC loop iteration 570 / 1000
# First loop: Outer MC loop iteration 571 / 1000
# First loop: Outer MC loop iteration 572 / 1000
# First loop: Outer MC loop iteration 573 / 1000
# First loop: Outer MC loop iteration 574 / 1000
# First loop: Outer MC loop iteration 575 / 1000
# First loop: Outer MC loop iteration 576 / 1000
# First loop: Outer MC loop iteration 577 / 1000
# First loop: Outer MC loop iteration 578 / 1000
# First loop: Outer MC loop iteration 579 / 1000
# First loop: Outer MC loop iteration 580 / 1000
# First loop: Outer MC loop iteration 581 / 1000
# First loop: Outer MC loop iteration 582 / 1000
# First loop: Outer MC loop iteration 583 / 1000
# First loop: Outer MC loop iteration 584 / 1000
# First loop: Outer MC loop iteration 585 / 1000
# First loop: Outer MC loop iteration 586 / 1000
# First loop: Outer MC loop iteration 587 / 1000
# First loop: Outer MC loop iteration 588 / 1000
# First loop: Outer MC loop iteration 589 / 1000
# First loop: Outer MC loop iteration 590 / 1000
# First loop: Outer MC loop iteration 591 / 1000
# First loop: Outer MC loop iteration 592 / 1000
# First loop: Outer MC loop iteration 593 / 1000
# First loop: Outer MC loop iteration 594 / 1000
# First loop: Outer MC loop iteration 595 / 1000
# First loop: Outer MC loop iteration 596 / 1000
# First loop: Outer MC loop iteration 597 / 1000
# First loop: Outer MC loop iteration 598 / 1000
# First loop: Outer MC loop iteration 599 / 1000
# First loop: Outer MC loop iteration 600 / 1000
# First loop: Outer MC loop iteration 601 / 1000
# First loop: Outer MC loop iteration 602 / 1000
# First loop: Outer MC loop iteration 603 / 1000
# First loop: Outer MC loop iteration 604 / 1000
# First loop: Outer MC loop iteration 605 / 1000
# First loop: Outer MC loop iteration 606 / 1000
# First loop: Outer MC loop iteration 607 / 1000
# First loop: Outer MC loop iteration 608 / 1000
# First loop: Outer MC loop iteration 609 / 1000
# First loop: Outer MC loop iteration 610 / 1000
# First loop: Outer MC loop iteration 611 / 1000
# First loop: Outer MC loop iteration 612 / 1000
# First loop: Outer MC loop iteration 613 / 1000
# First loop: Outer MC loop iteration 614 / 1000
# First loop: Outer MC loop iteration 615 / 1000
# First loop: Outer MC loop iteration 616 / 1000
# First loop: Outer MC loop iteration 617 / 1000
# First loop: Outer MC loop iteration 618 / 1000
# First loop: Outer MC loop iteration 619 / 1000
# First loop: Outer MC loop iteration 620 / 1000
# First loop: Outer MC loop iteration 621 / 1000
# First loop: Outer MC loop iteration 622 / 1000
# First loop: Outer MC loop iteration 623 / 1000
# First loop: Outer MC loop iteration 624 / 1000
# First loop: Outer MC loop iteration 625 / 1000
# First loop: Outer MC loop iteration 626 / 1000
# First loop: Outer MC loop iteration 627 / 1000
# First loop: Outer MC loop iteration 628 / 1000
# First loop: Outer MC loop iteration 629 / 1000
# First loop: Outer MC loop iteration 630 / 1000
# First loop: Outer MC loop iteration 631 / 1000
# First loop: Outer MC loop iteration 632 / 1000
# First loop: Outer MC loop iteration 633 / 1000
# First loop: Outer MC loop iteration 634 / 1000
# First loop: Outer MC loop iteration 635 / 1000
# First loop: Outer MC loop iteration 636 / 1000
# First loop: Outer MC loop iteration 637 / 1000
# First loop: Outer MC loop iteration 638 / 1000
# First loop: Outer MC loop iteration 639 / 1000
# First loop: Outer MC loop iteration 640 / 1000
# First loop: Outer MC loop iteration 641 / 1000
# First loop: Outer MC loop iteration 642 / 1000
# First loop: Outer MC loop iteration 643 / 1000
# First loop: Outer MC loop iteration 644 / 1000
# First loop: Outer MC loop iteration 645 / 1000
# First loop: Outer MC loop iteration 646 / 1000
# First loop: Outer MC loop iteration 647 / 1000
# First loop: Outer MC loop iteration 648 / 1000
# First loop: Outer MC loop iteration 649 / 1000
# First loop: Outer MC loop iteration 650 / 1000
# First loop: Outer MC loop iteration 651 / 1000
# First loop: Outer MC loop iteration 652 / 1000
# First loop: Outer MC loop iteration 653 / 1000
# First loop: Outer MC loop iteration 654 / 1000
# First loop: Outer MC loop iteration 655 / 1000
# First loop: Outer MC loop iteration 656 / 1000
# First loop: Outer MC loop iteration 657 / 1000
# First loop: Outer MC loop iteration 658 / 1000
# First loop: Outer MC loop iteration 659 / 1000
# First loop: Outer MC loop iteration 660 / 1000
# First loop: Outer MC loop iteration 661 / 1000
# First loop: Outer MC loop iteration 662 / 1000
# First loop: Outer MC loop iteration 663 / 1000
# First loop: Outer MC loop iteration 664 / 1000
# First loop: Outer MC loop iteration 665 / 1000
# First loop: Outer MC loop iteration 666 / 1000
# First loop: Outer MC loop iteration 667 / 1000
# First loop: Outer MC loop iteration 668 / 1000
# First loop: Outer MC loop iteration 669 / 1000
# First loop: Outer MC loop iteration 670 / 1000
# First loop: Outer MC loop iteration 671 / 1000
# First loop: Outer MC loop iteration 672 / 1000
# First loop: Outer MC loop iteration 673 / 1000
# First loop: Outer MC loop iteration 674 / 1000
# First loop: Outer MC loop iteration 675 / 1000
# First loop: Outer MC loop iteration 676 / 1000
# First loop: Outer MC loop iteration 677 / 1000
# First loop: Outer MC loop iteration 678 / 1000
# First loop: Outer MC loop iteration 679 / 1000
# First loop: Outer MC loop iteration 680 / 1000
# First loop: Outer MC loop iteration 681 / 1000
# First loop: Outer MC loop iteration 682 / 1000
# First loop: Outer MC loop iteration 683 / 1000
# First loop: Outer MC loop iteration 684 / 1000
# First loop: Outer MC loop iteration 685 / 1000
# First loop: Outer MC loop iteration 686 / 1000
# First loop: Outer MC loop iteration 687 / 1000
# First loop: Outer MC loop iteration 688 / 1000
# First loop: Outer MC loop iteration 689 / 1000
# First loop: Outer MC loop iteration 690 / 1000
# First loop: Outer MC loop iteration 691 / 1000
# First loop: Outer MC loop iteration 692 / 1000
# First loop: Outer MC loop iteration 693 / 1000
# First loop: Outer MC loop iteration 694 / 1000
# First loop: Outer MC loop iteration 695 / 1000
# First loop: Outer MC loop iteration 696 / 1000
# First loop: Outer MC loop iteration 697 / 1000
# First loop: Outer MC loop iteration 698 / 1000
# First loop: Outer MC loop iteration 699 / 1000
# First loop: Outer MC loop iteration 700 / 1000
# First loop: Outer MC loop iteration 701 / 1000
# First loop: Outer MC loop iteration 702 / 1000
# First loop: Outer MC loop iteration 703 / 1000
# First loop: Outer MC loop iteration 704 / 1000
# First loop: Outer MC loop iteration 705 / 1000
# First loop: Outer MC loop iteration 706 / 1000
# First loop: Outer MC loop iteration 707 / 1000
# First loop: Outer MC loop iteration 708 / 1000
# First loop: Outer MC loop iteration 709 / 1000
# First loop: Outer MC loop iteration 710 / 1000
# First loop: Outer MC loop iteration 711 / 1000
# First loop: Outer MC loop iteration 712 / 1000
# First loop: Outer MC loop iteration 713 / 1000
# First loop: Outer MC loop iteration 714 / 1000
# First loop: Outer MC loop iteration 715 / 1000
# First loop: Outer MC loop iteration 716 / 1000
# First loop: Outer MC loop iteration 717 / 1000
# First loop: Outer MC loop iteration 718 / 1000
# First loop: Outer MC loop iteration 719 / 1000
# First loop: Outer MC loop iteration 720 / 1000
# First loop: Outer MC loop iteration 721 / 1000
# First loop: Outer MC loop iteration 722 / 1000
# First loop: Outer MC loop iteration 723 / 1000
# First loop: Outer MC loop iteration 724 / 1000
# First loop: Outer MC loop iteration 725 / 1000
# First loop: Outer MC loop iteration 726 / 1000
# First loop: Outer MC loop iteration 727 / 1000
# First loop: Outer MC loop iteration 728 / 1000
# First loop: Outer MC loop iteration 729 / 1000
# First loop: Outer MC loop iteration 730 / 1000
# First loop: Outer MC loop iteration 731 / 1000
# First loop: Outer MC loop iteration 732 / 1000
# First loop: Outer MC loop iteration 733 / 1000
# First loop: Outer MC loop iteration 734 / 1000
# First loop: Outer MC loop iteration 735 / 1000
# First loop: Outer MC loop iteration 736 / 1000
# First loop: Outer MC loop iteration 737 / 1000
# First loop: Outer MC loop iteration 738 / 1000
# First loop: Outer MC loop iteration 739 / 1000
# First loop: Outer MC loop iteration 740 / 1000
# First loop: Outer MC loop iteration 741 / 1000
# First loop: Outer MC loop iteration 742 / 1000
# First loop: Outer MC loop iteration 743 / 1000
# First loop: Outer MC loop iteration 744 / 1000
# First loop: Outer MC loop iteration 745 / 1000
# First loop: Outer MC loop iteration 746 / 1000
# First loop: Outer MC loop iteration 747 / 1000
# First loop: Outer MC loop iteration 748 / 1000
# First loop: Outer MC loop iteration 749 / 1000
# First loop: Outer MC loop iteration 750 / 1000
# First loop: Outer MC loop iteration 751 / 1000
# First loop: Outer MC loop iteration 752 / 1000
# First loop: Outer MC loop iteration 753 / 1000
# First loop: Outer MC loop iteration 754 / 1000
# First loop: Outer MC loop iteration 755 / 1000
# First loop: Outer MC loop iteration 756 / 1000
# First loop: Outer MC loop iteration 757 / 1000
# First loop: Outer MC loop iteration 758 / 1000
# First loop: Outer MC loop iteration 759 / 1000
# First loop: Outer MC loop iteration 760 / 1000
# First loop: Outer MC loop iteration 761 / 1000
# First loop: Outer MC loop iteration 762 / 1000
# First loop: Outer MC loop iteration 763 / 1000
# First loop: Outer MC loop iteration 764 / 1000
# First loop: Outer MC loop iteration 765 / 1000
# First loop: Outer MC loop iteration 766 / 1000
# First loop: Outer MC loop iteration 767 / 1000
# First loop: Outer MC loop iteration 768 / 1000
# First loop: Outer MC loop iteration 769 / 1000
# First loop: Outer MC loop iteration 770 / 1000
# First loop: Outer MC loop iteration 771 / 1000
# First loop: Outer MC loop iteration 772 / 1000
# First loop: Outer MC loop iteration 773 / 1000
# First loop: Outer MC loop iteration 774 / 1000
# First loop: Outer MC loop iteration 775 / 1000
# First loop: Outer MC loop iteration 776 / 1000
# First loop: Outer MC loop iteration 777 / 1000
# First loop: Outer MC loop iteration 778 / 1000
# First loop: Outer MC loop iteration 779 / 1000
# First loop: Outer MC loop iteration 780 / 1000
# First loop: Outer MC loop iteration 781 / 1000
# First loop: Outer MC loop iteration 782 / 1000
# First loop: Outer MC loop iteration 783 / 1000
# First loop: Outer MC loop iteration 784 / 1000
# First loop: Outer MC loop iteration 785 / 1000
# First loop: Outer MC loop iteration 786 / 1000
# First loop: Outer MC loop iteration 787 / 1000
# First loop: Outer MC loop iteration 788 / 1000
# First loop: Outer MC loop iteration 789 / 1000
# First loop: Outer MC loop iteration 790 / 1000
# First loop: Outer MC loop iteration 791 / 1000
# First loop: Outer MC loop iteration 792 / 1000
# First loop: Outer MC loop iteration 793 / 1000
# First loop: Outer MC loop iteration 794 / 1000
# First loop: Outer MC loop iteration 795 / 1000
# First loop: Outer MC loop iteration 796 / 1000
# First loop: Outer MC loop iteration 797 / 1000
# First loop: Outer MC loop iteration 798 / 1000
# First loop: Outer MC loop iteration 799 / 1000
# First loop: Outer MC loop iteration 800 / 1000
# First loop: Outer MC loop iteration 801 / 1000
# First loop: Outer MC loop iteration 802 / 1000
# First loop: Outer MC loop iteration 803 / 1000
# First loop: Outer MC loop iteration 804 / 1000
# First loop: Outer MC loop iteration 805 / 1000
# First loop: Outer MC loop iteration 806 / 1000
# First loop: Outer MC loop iteration 807 / 1000
# First loop: Outer MC loop iteration 808 / 1000
# First loop: Outer MC loop iteration 809 / 1000
# First loop: Outer MC loop iteration 810 / 1000
# First loop: Outer MC loop iteration 811 / 1000
# First loop: Outer MC loop iteration 812 / 1000
# First loop: Outer MC loop iteration 813 / 1000
# First loop: Outer MC loop iteration 814 / 1000
# First loop: Outer MC loop iteration 815 / 1000
# First loop: Outer MC loop iteration 816 / 1000
# First loop: Outer MC loop iteration 817 / 1000
# First loop: Outer MC loop iteration 818 / 1000
# First loop: Outer MC loop iteration 819 / 1000
# First loop: Outer MC loop iteration 820 / 1000
# First loop: Outer MC loop iteration 821 / 1000
# First loop: Outer MC loop iteration 822 / 1000
# First loop: Outer MC loop iteration 823 / 1000
# First loop: Outer MC loop iteration 824 / 1000
# First loop: Outer MC loop iteration 825 / 1000
# First loop: Outer MC loop iteration 826 / 1000
# First loop: Outer MC loop iteration 827 / 1000
# First loop: Outer MC loop iteration 828 / 1000
# First loop: Outer MC loop iteration 829 / 1000
# First loop: Outer MC loop iteration 830 / 1000
# First loop: Outer MC loop iteration 831 / 1000
# First loop: Outer MC loop iteration 832 / 1000
# First loop: Outer MC loop iteration 833 / 1000
# First loop: Outer MC loop iteration 834 / 1000
# First loop: Outer MC loop iteration 835 / 1000
# First loop: Outer MC loop iteration 836 / 1000
# First loop: Outer MC loop iteration 837 / 1000
# First loop: Outer MC loop iteration 838 / 1000
# First loop: Outer MC loop iteration 839 / 1000
# First loop: Outer MC loop iteration 840 / 1000
# First loop: Outer MC loop iteration 841 / 1000
# First loop: Outer MC loop iteration 842 / 1000
# First loop: Outer MC loop iteration 843 / 1000
# First loop: Outer MC loop iteration 844 / 1000
# First loop: Outer MC loop iteration 845 / 1000
# First loop: Outer MC loop iteration 846 / 1000
# First loop: Outer MC loop iteration 847 / 1000
# First loop: Outer MC loop iteration 848 / 1000
# First loop: Outer MC loop iteration 849 / 1000
# First loop: Outer MC loop iteration 850 / 1000
# First loop: Outer MC loop iteration 851 / 1000
# First loop: Outer MC loop iteration 852 / 1000
# First loop: Outer MC loop iteration 853 / 1000
# First loop: Outer MC loop iteration 854 / 1000
# First loop: Outer MC loop iteration 855 / 1000
# First loop: Outer MC loop iteration 856 / 1000
# First loop: Outer MC loop iteration 857 / 1000
# First loop: Outer MC loop iteration 858 / 1000
# First loop: Outer MC loop iteration 859 / 1000
# First loop: Outer MC loop iteration 860 / 1000
# First loop: Outer MC loop iteration 861 / 1000
# First loop: Outer MC loop iteration 862 / 1000
# First loop: Outer MC loop iteration 863 / 1000
# First loop: Outer MC loop iteration 864 / 1000
# First loop: Outer MC loop iteration 865 / 1000
# First loop: Outer MC loop iteration 866 / 1000
# First loop: Outer MC loop iteration 867 / 1000
# First loop: Outer MC loop iteration 868 / 1000
# First loop: Outer MC loop iteration 869 / 1000
# First loop: Outer MC loop iteration 870 / 1000
# First loop: Outer MC loop iteration 871 / 1000
# First loop: Outer MC loop iteration 872 / 1000
# First loop: Outer MC loop iteration 873 / 1000
# First loop: Outer MC loop iteration 874 / 1000
# First loop: Outer MC loop iteration 875 / 1000
# First loop: Outer MC loop iteration 876 / 1000
# First loop: Outer MC loop iteration 877 / 1000
# First loop: Outer MC loop iteration 878 / 1000
# First loop: Outer MC loop iteration 879 / 1000
# First loop: Outer MC loop iteration 880 / 1000
# First loop: Outer MC loop iteration 881 / 1000
# First loop: Outer MC loop iteration 882 / 1000
# First loop: Outer MC loop iteration 883 / 1000
# First loop: Outer MC loop iteration 884 / 1000
# First loop: Outer MC loop iteration 885 / 1000
# First loop: Outer MC loop iteration 886 / 1000
# First loop: Outer MC loop iteration 887 / 1000
# First loop: Outer MC loop iteration 888 / 1000
# First loop: Outer MC loop iteration 889 / 1000
# First loop: Outer MC loop iteration 890 / 1000
# First loop: Outer MC loop iteration 891 / 1000
# First loop: Outer MC loop iteration 892 / 1000
# First loop: Outer MC loop iteration 893 / 1000
# First loop: Outer MC loop iteration 894 / 1000
# First loop: Outer MC loop iteration 895 / 1000
# First loop: Outer MC loop iteration 896 / 1000
# First loop: Outer MC loop iteration 897 / 1000
# First loop: Outer MC loop iteration 898 / 1000
# First loop: Outer MC loop iteration 899 / 1000
# First loop: Outer MC loop iteration 900 / 1000
# First loop: Outer MC loop iteration 901 / 1000
# First loop: Outer MC loop iteration 902 / 1000
# First loop: Outer MC loop iteration 903 / 1000
# First loop: Outer MC loop iteration 904 / 1000
# First loop: Outer MC loop iteration 905 / 1000
# First loop: Outer MC loop iteration 906 / 1000
# First loop: Outer MC loop iteration 907 / 1000
# First loop: Outer MC loop iteration 908 / 1000
# First loop: Outer MC loop iteration 909 / 1000
# First loop: Outer MC loop iteration 910 / 1000
# First loop: Outer MC loop iteration 911 / 1000
# First loop: Outer MC loop iteration 912 / 1000
# First loop: Outer MC loop iteration 913 / 1000
# First loop: Outer MC loop iteration 914 / 1000
# First loop: Outer MC loop iteration 915 / 1000
# First loop: Outer MC loop iteration 916 / 1000
# First loop: Outer MC loop iteration 917 / 1000
# First loop: Outer MC loop iteration 918 / 1000
# First loop: Outer MC loop iteration 919 / 1000
# First loop: Outer MC loop iteration 920 / 1000
# First loop: Outer MC loop iteration 921 / 1000
# First loop: Outer MC loop iteration 922 / 1000
# First loop: Outer MC loop iteration 923 / 1000
# First loop: Outer MC loop iteration 924 / 1000
# First loop: Outer MC loop iteration 925 / 1000
# First loop: Outer MC loop iteration 926 / 1000
# First loop: Outer MC loop iteration 927 / 1000
# First loop: Outer MC loop iteration 928 / 1000
# First loop: Outer MC loop iteration 929 / 1000
# First loop: Outer MC loop iteration 930 / 1000
# First loop: Outer MC loop iteration 931 / 1000
# First loop: Outer MC loop iteration 932 / 1000
# First loop: Outer MC loop iteration 933 / 1000
# First loop: Outer MC loop iteration 934 / 1000
# First loop: Outer MC loop iteration 935 / 1000
# First loop: Outer MC loop iteration 936 / 1000
# First loop: Outer MC loop iteration 937 / 1000
# First loop: Outer MC loop iteration 938 / 1000
# First loop: Outer MC loop iteration 939 / 1000
# First loop: Outer MC loop iteration 940 / 1000
# First loop: Outer MC loop iteration 941 / 1000
# First loop: Outer MC loop iteration 942 / 1000
# First loop: Outer MC loop iteration 943 / 1000
# First loop: Outer MC loop iteration 944 / 1000
# First loop: Outer MC loop iteration 945 / 1000
# First loop: Outer MC loop iteration 946 / 1000
# First loop: Outer MC loop iteration 947 / 1000
# First loop: Outer MC loop iteration 948 / 1000
# First loop: Outer MC loop iteration 949 / 1000
# First loop: Outer MC loop iteration 950 / 1000
# First loop: Outer MC loop iteration 951 / 1000
# First loop: Outer MC loop iteration 952 / 1000
# First loop: Outer MC loop iteration 953 / 1000
# First loop: Outer MC loop iteration 954 / 1000
# First loop: Outer MC loop iteration 955 / 1000
# First loop: Outer MC loop iteration 956 / 1000
# First loop: Outer MC loop iteration 957 / 1000
# First loop: Outer MC loop iteration 958 / 1000
# First loop: Outer MC loop iteration 959 / 1000
# First loop: Outer MC loop iteration 960 / 1000
# First loop: Outer MC loop iteration 961 / 1000
# First loop: Outer MC loop iteration 962 / 1000
# First loop: Outer MC loop iteration 963 / 1000
# First loop: Outer MC loop iteration 964 / 1000
# First loop: Outer MC loop iteration 965 / 1000
# First loop: Outer MC loop iteration 966 / 1000
# First loop: Outer MC loop iteration 967 / 1000
# First loop: Outer MC loop iteration 968 / 1000
# First loop: Outer MC loop iteration 969 / 1000
# First loop: Outer MC loop iteration 970 / 1000
# First loop: Outer MC loop iteration 971 / 1000
# First loop: Outer MC loop iteration 972 / 1000
# First loop: Outer MC loop iteration 973 / 1000
# First loop: Outer MC loop iteration 974 / 1000
# First loop: Outer MC loop iteration 975 / 1000
# First loop: Outer MC loop iteration 976 / 1000
# First loop: Outer MC loop iteration 977 / 1000
# First loop: Outer MC loop iteration 978 / 1000
# First loop: Outer MC loop iteration 979 / 1000
# First loop: Outer MC loop iteration 980 / 1000
# First loop: Outer MC loop iteration 981 / 1000
# First loop: Outer MC loop iteration 982 / 1000
# First loop: Outer MC loop iteration 983 / 1000
# First loop: Outer MC loop iteration 984 / 1000
# First loop: Outer MC loop iteration 985 / 1000
# First loop: Outer MC loop iteration 986 / 1000
# First loop: Outer MC loop iteration 987 / 1000
# First loop: Outer MC loop iteration 988 / 1000
# First loop: Outer MC loop iteration 989 / 1000
# First loop: Outer MC loop iteration 990 / 1000
# First loop: Outer MC loop iteration 991 / 1000
# First loop: Outer MC loop iteration 992 / 1000
# First loop: Outer MC loop iteration 993 / 1000
# First loop: Outer MC loop iteration 994 / 1000
# First loop: Outer MC loop iteration 995 / 1000
# First loop: Outer MC loop iteration 996 / 1000
# First loop: Outer MC loop iteration 997 / 1000
# First loop: Outer MC loop iteration 998 / 1000
# First loop: Outer MC loop iteration 999 / 1000
# First loop: Outer MC loop iteration 1000 / 1000
# Second loop: 1 / 1000
# Second loop: 2 / 1000
# Second loop: 3 / 1000
# Second loop: 4 / 1000
# Second loop: 5 / 1000
# Second loop: 6 / 1000
# Second loop: 7 / 1000
# Second loop: 8 / 1000
# Second loop: 9 / 1000
# Second loop: 10 / 1000
# Second loop: 11 / 1000
# Second loop: 12 / 1000
# Second loop: 13 / 1000
# Second loop: 14 / 1000
# Second loop: 15 / 1000
# Second loop: 16 / 1000
# Second loop: 17 / 1000
# Second loop: 18 / 1000
# Second loop: 19 / 1000
# Second loop: 20 / 1000
# Second loop: 21 / 1000
# Second loop: 22 / 1000
# Second loop: 23 / 1000
# Second loop: 24 / 1000
# Second loop: 25 / 1000
# Second loop: 26 / 1000
# Second loop: 27 / 1000
# Second loop: 28 / 1000
# Second loop: 29 / 1000
# Second loop: 30 / 1000
# Second loop: 31 / 1000
# Second loop: 32 / 1000
# Second loop: 33 / 1000
# Second loop: 34 / 1000
# Second loop: 35 / 1000
# Second loop: 36 / 1000
# Second loop: 37 / 1000
# Second loop: 38 / 1000
# Second loop: 39 / 1000
# Second loop: 40 / 1000
# Second loop: 41 / 1000
# Second loop: 42 / 1000
# Second loop: 43 / 1000
# Second loop: 44 / 1000
# Second loop: 45 / 1000
# Second loop: 46 / 1000
# Second loop: 47 / 1000
# Second loop: 48 / 1000
# ...
# Loop: 49207 / 50000
# Loop: 49208 / 50000
# Loop: 49209 / 50000
# Loop: 49210 / 50000
# Loop: 49211 / 50000
# Loop: 49212 / 50000
# Loop: 49213 / 50000
# Loop: 49214 / 50000
# Loop: 49215 / 50000
# Loop: 49216 / 50000
# Loop: 49217 / 50000
# Loop: 49218 / 50000
# Loop: 49219 / 50000
# Loop: 49220 / 50000
# Loop: 49221 / 50000
# Loop: 49222 / 50000
# Loop: 49223 / 50000
# Loop: 49224 / 50000
# Loop: 49225 / 50000
# Loop: 49226 / 50000
# Loop: 49227 / 50000
# Loop: 49228 / 50000
# Loop: 49229 / 50000
# Loop: 49230 / 50000
# Loop: 49231 / 50000
# Loop: 49232 / 50000
# Loop: 49233 / 50000
# Loop: 49234 / 50000
# Loop: 49235 / 50000
# Loop: 49236 / 50000
# Loop: 49237 / 50000
# Loop: 49238 / 50000
# Loop: 49239 / 50000
# Loop: 49240 / 50000
# Loop: 49241 / 50000
# Loop: 49242 / 50000
# Loop: 49243 / 50000
# Loop: 49244 / 50000
# Loop: 49245 / 50000
# Loop: 49246 / 50000
# Loop: 49247 / 50000
